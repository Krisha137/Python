# %% [markdown]
# # Introduction Of Machine Learning Using Python

# %%
import pandas as pd
import numpy as np

data=pd.DataFrame({
    "OriginalFeature":[1,2,3,4,5,6,7],
    "CategoricalFeature":['A','B','A','B','A','B','A']})

data
# Out:
#    OriginalFeature CategoricalFeature
# 0                1                  A
# 1                2                  B
# 2                3                  A
# 3                4                  B
# 4                5                  A
# 5                6                  B
# 6                7                  A

# %%
# One-Hot Encoding

data1=pd.get_dummies(data,columns=['CategoricalFeature'])
data1
# Out:
#    OriginalFeature  CategoricalFeature_A  CategoricalFeature_B
# 0                1                  True                 False
# 1                2                 False                  True
# 2                3                  True                 False
# 3                4                 False                  True
# 4                5                  True                 False
# 5                6                 False                  True
# 6                7                  True                 False

# %%
# One-Hot Encoding

data1=pd.get_dummies(data,columns=['CategoricalFeature'],drop_first=True)
data1
# Out:
#    OriginalFeature  CategoricalFeature_B
# 0                1                 False
# 1                2                  True
# 2                3                 False
# 3                4                  True
# 4                5                 False
# 5                6                  True
# 6                7                 False

# %%
# EDA - Exploratory Data Analysis

import pandas as pd
df=pd.read_csv("car data.csv")
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.drop('Car_Name',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
pd.get_dummies(df) # One-hot Encoding in ML (Technique for Feature Transformation)
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_CNG  \
# 0    2014           3.35           5.59       27000      0          False
# 1    2013           4.75           9.54       43000      0          False
# 2    2017           7.25           9.85        6900      0          False
# 3    2011           2.85           4.15        5200      0          False
# 4    2014           4.60           6.87       42450      0          False
# ..    ...            ...            ...         ...    ...            ...
# 296  2016           9.50          11.60       33988      0          False
# 297  2015           4.00           5.90       60000      0          False
# 298  2009           3.35          11.00       87934      0          False
# 299  2017          11.50          12.50        9000      0          False
# 300  2016           5.30           5.90        5464      0          False
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Dealer  \
# ...

# %%
df=pd.get_dummies(df,drop_first=True)
# 3 column dropped.We can get conclusion if its not petrol or diesel than it will be CNG
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# 0  2014           3.35           5.59       27000      0             False
# 1  2013           4.75           9.54       43000      0              True
# 2  2017           7.25           9.85        6900      0             False
# 3  2011           2.85           4.15        5200      0             False
# 4  2014           4.60           6.87       42450      0              True
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0              True                   False                 True
# 1             False                   False                 True
# 2              True                   False                 True
# 3              True                   False                 True
# 4             False                   False                 True

# %% [markdown]
# # Adding a New features

# %%
import pandas as pd

# Defining Features
room_length=[18,20,10,12,18,11]
room_breadth=[20,20,10,11,19,10]
room_type=['Big','Big','Normal','Normal','Big','Normal']

# Creating a data Frame
data=pd.DataFrame({'Length':room_length,'Breadth':room_breadth,'Type':room_type})
data
# Out:
#    Length  Breadth    Type
# 0      18       20     Big
# 1      20       20     Big
# 2      10       10  Normal
# 3      12       11  Normal
# 4      18       19     Big
# 5      11       10  Normal

# %%
# Adding a feature called area from Length and Breadth

data['Area']=data['Length']*data['Breadth']
data
# Out:
#    Length  Breadth    Type  Area
# 0      18       20     Big   360
# 1      20       20     Big   400
# 2      10       10  Normal   100
# 3      12       11  Normal   132
# 4      18       19     Big   342
# 5      11       10  Normal   110

# %%
data[data['Area']>300]
# Out:
#    Length  Breadth Type  Area
# 0      18       20  Big   360
# 1      20       20  Big   400
# 4      18       19  Big   342

# %% [markdown]
# # Encoding Nominal Variables

# %% [markdown]
# # Transforming Numeric (continuous) Features to Categorical Features

# %%
# Defining Features
apartment_area=[4720,2430,4368,3969,6142,7912]
apartment_price=[2360000,1215000,2184000,1984500,3071000,3956000]

# Creating a data Frame
data4=pd.DataFrame({'Area':apartment_area,'Price':apartment_price})
data4
# Out:
#    Area    Price
# 0  4720  2360000
# 1  2430  1215000
# 2  4368  2184000
# 3  3969  1984500
# 4  6142  3071000
# 5  7912  3956000

# %%
import numpy as np
data4['Price']=np.where(data4['Price']>3000000,'High',np.where(data4['Price']<2000000,'Low','Medium'))
data4
# Out:
#    Area   Price
# 0  4720  Medium
# 1  2430     Low
# 2  4368  Medium
# 3  3969     Low
# 4  6142    High
# 5  7912    High

# %% [markdown]
# # Train Validation Split

# %% [markdown]
# # 9 Marks Tasks

# %%
import pandas as pd
df=pd.read_csv("ipl-matches.csv")
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# How many matches won by Gujrat Titans in Superover

df[(df['SuperOver']=='Y')& (df['WinningTeam']=='Gujarat Titans')].shape[0]
# Out:
# 0

# %%
# How many matches won by RCB vs KKR

df[((df["WinningTeam"]=="Royal Challengers Bangalore")&(((df["Team1"]=="Royal Challengers Bangalore") & (df["Team2"]=="Kolkata Knight Riders"))|(df["Team1"]=="Kolkata Knight Riders") & (df["Team2"]=="Royal Challengers Bangalore")))].shape[0]
# Out:
# 14
