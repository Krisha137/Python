# %% [markdown]
# # Write a function cust_data() to ask user to enter their names and age to store data in customer.txt file.

# %%
def cust_data():
    f=open("customer.txt","a")
    while True:
        n=input("Enter Name Of Customer :")
        a=int(input("Enter Age Of Customer :"))
        s=input("If You Want to exit then press 'q' :")
        
        d=n+" - "+str(a)+"\n"
        f.write(d)
        if s.lower()=='q':
            break
    f.close()
cust_data()
# Out:
# Enter Name Of Customer : Krisha
# Enter Age Of Customer : 18
# If You Want to exit then press 'q' : a
# Enter Name Of Customer : Angle
# Enter Age Of Customer : 19
# If You Want to exit then press 'q' : a
# Enter Name Of Customer : Priyal
# Enter Age Of Customer : 18
# If You Want to exit then press 'q' : q

# %% [markdown]
# # Write a python program to create and read the city.txt file in one go and print the contents on the output screen.

# %%
f=open("city.txt","w+")
l=["Mumbai\n","Surat\n","Ahemdabad\n","Gandhinagar\n","Goa\n","Dubai\n"]
f.writelines(l)
f.seek(0)
for i in f.readlines():
    print(i)
# Out:
# Mumbai
#
# Surat
#
# Ahemdabad
#
# Gandhinagar
#
# Goa
#
# Dubai

# %% [markdown]
# # Write a function count_lines() to count and display the total number of lines from the file. Consider the following lines for the file – friends.txt.
# ### Friends are crazy, Friends are naughty !
# ### Friends are honest, Friends are best !
# ### Friends are like keygen, friends are like license key !
# ### We are nothing without friends, Life is not possible without friends !

# %%
f=open("friends.txt")
li=f.readlines()
l=len(li)
print("No. Of Lines Are :",l)
# Out:
# No. Of Lines Are : 4

# %% [markdown]
# # Write a function display_oddLines() to display odd number lines from the text file. Consider the following lines for the file– friends.txt.
# ### Friends are crazy, Friends are naughty !
# ### Friends are honest, Friends are best !
# ### Friends are like keygen, friends are like license key !
# ### We are nothing without friends, Life is not possible without friends !

# %%
# Odd Line______
f=open("friends.txt")
l=f.readlines()
for i in range(len(l)):
    if i%2==0:
        print(l[i])
# Out:
# Friends are crazy, Friends are naughty !
#
# Friends are like keygen, friends are like license key !

# %%
# Even Line_______
f=open("friends.txt")
l=f.readlines()
for i in range(len(l)):
    if i%2!=0:
        print(l[i])
# Out:
# Friends are honest, Friends are best !
#
# We are nothing without friends, Life is not possible without friends !

# %% [markdown]
# # Write a Python program to read a text file and do following: 1. Print no. of words 2. Print no. statements

# %%
f=open("friends.txt")
w=f.read().split()
print("No. Of Words :",len(w))
f.seek(0)
r=str.maketrans("?.!","|||")
s=f.read().translate(r).split("|")
s=[x for x in s if x.strip()!=" "]
print("No. Of Statements :",len(s))
# Out:
# No. Of Words : 37
# No. Of Statements : 5

# %% [markdown]
# # Write a python program that reads a text file and changes the file by capitalizing each character of file.

# %%
f=open("friends.txt")
d=f.read().upper()
f.close()
f=open("friends.txt","w")
f.write(d)
f.close()

# %% [markdown]
# # Write a Python program to copy the contents of a file to another file.

# %%
f1=open("friends.txt")
f2=open("copy.txt","w")
f2.write(f1.read())
f1.close()
f2.close()

# %% [markdown]
# # Write a python program to read line by line from a given files file1 & file2 and write into file3.

# %%
f1=open("friends.txt")
f2=open("city.txt")
s1=f1.readlines()
s2=f2.readlines()
l=0
if len(s1)>len(s2):
    l=len(s1)
else:
    l=len(s2)
for i in range(l):
    if len(s1)>i:
        print(s1[i])
    if len(s2)>i:
        print(s2[i])
# Out:
# Friends are crazy, Friends are naughty !
#
# Mumbai
#
# Friends 6re honest, Friends are best !
#
# Surat
#
# Friends are like keygen, friends are like license key !
#
# Ahemdabad
#
# new We are nothing without friends, Life is not possible without friends !
# Gandhinagar
#
# Goa
#
# Dubai

# %% [markdown]
# # Write python program to count the number of lines in a file.

# %%
f=open("friends.txt")
l=f.readlines()
print("NO. Of Lines :",len(l))
# Out:
# NO. Of Lines : 4

# %% [markdown]
# # Write a python program to search for a string in text files.

# %%
f=open("friends.txt")
d={}
s=f.read().split()
for i in range(len(s)):
    if s[i] in d:
        d[s[i]]+=1
    else:
        d[s[i]]=1
print(d)
# Out:
# {'FRIENDS': 7, 'ARE': 7, 'CRAZY,': 1, 'NAUGHTY': 1, '!': 4, 'HONEST,': 1, 'BEST': 1, 'LIKE': 2, 'KEYGEN,': 1, 'LICENSE': 1, 'KEY': 1, 'WE': 1, 'NOTHING': 1, 'WITHOUT': 2, 'FRIENDS,': 1, 'LIFE': 1, 'IS': 1, 'NOT': 1, 'POSSIBLE': 1}

# %%
f=open("friends.txt")
d=f.read().split()
s=input("Enter String :")
c=0
for i in range(len(d)):
    if d[i]==s:
        c+=1
print(s,"'s ouccurence :",c)
# Out:
# Enter String : ARE
# ARE 's ouccurence : 7

# %% [markdown]
# # Write a “pager” program. Your solution should prompt for a filename, and display the text file 25 lines at a time, pausingeach time to ask the user to enter the word “continue”, in order to show the next 25 lines or enter the word “stop” toclose the file.

# %%
s=input("Enter File Name :")
sf=s+".txt"
f=open(sf)
b=True
while b:
    for i in range(5):
        x=f.readline()
        if x=="":
            b=False
            break
        print(x)
    if not b:
        break
    c=input("If you want to countinue then enter 'continue'  : ")
    if c.lower()=="continue":
        continue
    else:
        b=False    
f.close()
# Out:
# Enter File Name : city
# Mumbai
#
# Surat
#
# Ahemdabad
#
# Gandhinagar
#
# Goa
# If you want to countinue then enter 'continue'  :  continue
# Dubai
#
# Mumbai
#
# Surat
#
# Ahemdabad
#
# Gandhinagar
# If you want to countinue then enter 'continue'  :  continue
# Goa
#
# Dubai

# %% [markdown]
# # Write a Python program to reverse the content of a one file and store it in second file and also convert content of second file into uppercase and store it in third file and also count number of Vovels in third file and also print only second line from the content of third file.

# %%
f1=open("friends.txt")
f2=open("rev.txt","w+")
d=f1.read()
f2.write(d[::-1])
f1.close()
f2.seek(0)
d2=f2.read().upper()
f3=open("upp.txt","w+")
f3.write(d2)
f2.close()
f3.seek(0)
v=0
for i in f3.read():
    if i in ["A","E","I","O","U"]:
        v+=1
print("Vovel :",v)
# Out:
# Vovel : 22

# %% [markdown]
# # Write a python program to extract a list of all four-letter words that start and end with the same letter from given text file.

# %%
f=open("copy.txt")
d=f.read().split()
w=[]
for i in d:
    if len(i)==4:
        if i[0].lower()==i[-1].lower():
            w.append(i)
print(w)
# Out:
# ['Anna', 'noon', 'Otto']

# %% [markdown]
# # Write a python program to read a text file “Story.txt” and print only word starting with ‘I’ in reverse order.
# ## Example: If value in text file is : ‘INDIA IS MY COUNTRY’
# ## Output will be: ‘AIDNI SI MY COUNTRY’

# %%
f=open("copy.txt")
d=f.read().split()
l=[]
for i in d:
    if i[0].lower()=="i":
        l.append(i[::-1])
    else:
        l.append(i)
print(" ".join(l))
# Out:
# AIDNI SI MY COUNTRY

# %% [markdown]
# # Write a Python program to count words, characters and spaces from text file.
# ## Input:
# ### Python is a Easy Subject
# ### OOPs is One of the most
# ### interesting Topic
# ## Output:
# ### No of space: 10
# ### No of word: 13
# ### No of character: 64

# %%
f=open("copy.txt")
ch=0
s=0
for i in f.read():
    ch+=1
    if i.isspace():
        s+=1
f.seek(0)
d=f.readlines()
s=s-len(d)+1
ch=ch-len(d)+1
f.seek(0)
w=f.read().split()
print("No. Of Space : ",s)
print("No. Of Word : ",len(w))
print("No. Of Charactor : ",ch)
# Out:
# No. Of Space :  10
# No. Of Word :  13
# No. Of Charactor :  64

# %% [markdown]
# # File Filtering. write all lines of a file1, except those that start with a pound sign ( # ), the comment character for Python to file2. And display data of file2.
# ## Text file1 content:
# ### Friends are crazy, Friends are naughty !
# #### Friends are honest, Friends are best !
# ### Friends are like keygen, #friends are like license key !
# ### We are nothing without friends, Life is not possible without friends !
# ## Text file2 shoud be:
# ### Friends are crazy, Friends are naughty !
# ### Friends are like keygen,
# ### We are nothing without friends, Life is not possible without friends !

# %%
f1=open("copy.txt")
f2=open("friends.txt","w")
r1=f1.readlines()
for i in r1:
    if i[0]=="\n":
        continue
    else:
        if "#" in i:
            for j in range(len(i)):
                if i[j]=="#":
                    f2.write(i[:j:1]+"\n")
        else:
            f2.write(i)
f1.close()
f2.close()

# %% [markdown]
# # Write a python program to accept string/sentence from user till the user enters “END”. Each string/sentence entered by### user should be a newline in file. Save all the lines in file and display only those lines which begin with capital letter.
# ### Example:
# ### Enter Something (for quit enter END):Hi Friends
# ### Enter Something (for quit enter END):how are you all
# ### Enter Something (for quit enter END):I am fine
# ### Enter Something (for quit enter END):hope you all are fine
# ### Enter Something (for quit enter END):END
# ### The Line started with Capital Letters:
# ### Hi Friends
# ### I am fine

# %%
f=open("stu.txt","w+")
while True:
    s=input("Enter String If You Want To Exite Then Press 'END' :")
    if s.upper()=="END":
        break
    d=s+"\n"
    f.write(d)
f.seek(0)
for i in f.readlines():
    if i[0].isupper():
        print(i)
# Out:
# Enter String If You Want To Exite Then Press 'END' : Hi Friends
# Enter String If You Want To Exite Then Press 'END' : how are you all
# Enter String If You Want To Exite Then Press 'END' : I am fine
# Enter String If You Want To Exite Then Press 'END' : hope you all are fine
# Enter String If You Want To Exite Then Press 'END' : End
# Hi Friends
#
# I am fine

# %% [markdown]
# # Write a program to compare two text files. If they are different, give the line and column numbers in the files where thefirst difference occurs.
# ## Example:
# ## File 1: python1.txt
# ### Friends are crazy, Friends are naughty !
# ### Friends are honest, Friends are best !
# ### Friends are like keygen, friends are like license key !
# ### new We are nothing without friends, Life is not possible without friends !
# ## File 2: python2.txt
# ### Friends are crazy, Friends are naughty !
# ### Friends 6re honest, Friends are best !
# ### Friends are like keygen, friends are like license key !
# ### new We are nothing without friends, Life is not possible without friends !
# ## Output:
# ### line number 2 colNo. 9

# %%
f1=open("copy.txt")
f2=open("friends.txt")
r1=f1.read()
r2=f2.read()
c=n=1
for i in range(len(r1)):
    if r1[i]==r2[i]:
        c+=1
        if r1[i]=="\n":
            n+=1
            c=1
    else:
        print("Line : ",n," ColNo : ",c)
        c+=1
# Out:
# Line :  2  ColNo :  9

# %% [markdown]
# # Write a python program to read through the mbox-short.txt and figure out who hassent the greatest number of mail messages. The program looks for 'From ' lines andtakes the second word of those lines as the person who sent the mail. The programcreates a Python dictionary that maps the sender's mail address to a count of thenumber of times they appear in the file. After the dictionary is produced, the program reads through the dictionary toidentify the sender with the maximum count (the most prolific sender).
# ## Expected Output:
# ### {'stephen.marquard@uct.ac.za': 2, 'louis@media.berkeley.edu': 3, 'zqian@umich.edu': 4, 'rjlowe@iupui.edu': 2,'cwen@iupui.edu': 5, 'gsilver@umich.edu': 3, 'wagnermr@iupui.edu': 1, 'antranig@caret.cam.ac.uk': 1,'gopal.ramasammycook@gmail.com': 1, 'david.horwitz@uct.ac.za': 4, 'ray@media.berkeley.edu': 1}cwen@iupui.edu 5

# %%
f=open("city.txt")
d={}
l=f.readlines()
for i in l:
    if i.startswith("From "):
        word=i.split()
        v=word[1]
        if v in d:
            d[v]+=1
        else:
            d[v]=1
print(d)
mc=0
me=""
for e,c in d.items():
    if c>mc:
        mc=c
        me=e
print("Max Email :",me)
print("Max Count :",mc)
f.close()
# Out:
# {'stephen.marquard@uct.ac.za': 1, 'louis@media.berkeley.edu': 3, 'zqian@umich.edu': 4, 'rjlowe@iupui.edu': 1, 'cwen@iupui.edu': 4, 'gsilver@umich.edu': 1, 'wagnermr@iupui.edu': 1, 'antranig@caret.cam.ac.uk': 1, 'gopal.ramasammycook@gmail.com': 1, 'david.horwitz@uct.ac.za': 2, 'ray@media.berkeley.edu': 1}
# Max Email : zqian@umich.edu
# Max Count : 4

# %% [markdown]
# # Write a python program to make a module which contain all the basic functions related to string and import that modulein another file and use that fuctions with string given by user.

# %%
# %%writefile mod.py
def length(s):
    print("Length :",len(s))
def upperCase(s):
    print("Upper Case :",s.upper())
def lowerCase(s):
    print("Lower Case :",s.lower())
def reverse(s):
    print(s[::-1])
def vovel(s):
    c=0
    for i in s:
        if i.lower() in "aeiou":
            c+=1
    print("Count of Vovel :",c)
def palindrome(s):
    s=s.lower()
    if s==s[::-1]:
        print(s," is a Palindrom.")
    else:
        print(s," is Not a Palindrom.")
# Out:
# Overwriting mod.py

# %%
import mod
s=input("Input String :")
mod.length(s)
mod.upperCase(s)
mod.lowerCase(s)
mod.reverse(s)
mod.vovel(s)
mod.palindrome(s)
# Out:
# Input String : Madam
# Length : 5
# Upper Case : MADAM
# Lower Case : madam
# madaM
# Count of Vovel : 2
# madam
# madam  is a Palindrom.

# %%
import mod
s=input("Input String :")
mod.length(s)
mod.upperCase(s)
mod.lowerCase(s)
mod.reverse(s)
mod.vovel(s)
mod.palindrome(s)
# Out:
# Input String : Tejas Dada
# Length : 10
# Upper Case : TEJAS DADA
# Lower Case : tejas dada
# adaD sajeT
# Count of Vovel : 4
# adad sajet
# tejas dada  is Not a Palindrom.

# %% [markdown]
# # Write a python program to create a directory and subdirectory. It should print the current working directory path and list of names of files present in the given directory.

# %%
import os
print(os.getcwd())
print(os.listdir())
os.mkdir("v")
sub=os.path.join("v","rani")
os.mkdir(sub)
# Out:
# C:\Users\krish\krishupython
# ['.ipynb_checkpoints', 'abc.txt', 'city.txt', 'copy.txt', 'customer.txt', 'friends.txt', 'lec_16.ipynb', 'mod.py', 'python1.ipynb', 'python2.ipynb', 'Python3.ipynb', 'rev.txt', 'stu.txt', 'Untitled.ipynb', 'upp.txt', '__pycache__']

# %% [markdown]
# # Write a python program to make a module named cal.py which contain all the basic functions related to calculator like addition, subtraction, multiplication, and division import that module in another file and use that functions with number inputs given by user.

# %%
# %%writefile mod.py
def add(a,b):
    print("Addition :",a+b)
def sub(a,b):
    print("Substract :",a-b)
def mul(a,b):
    print("Multiplication :",a*b)
def div(a,b):
    print("Divition :",a/b)
# Out:
# Overwriting mod.py

# %%
import mod
a=int(input("Enter num 1 :"))
b=int(input("Enter num 2 :"))
mod.add(a,b)
mod.sub(a,b)
mod.mul(a,b)
mod.div(a,b)
# Out:
# Enter num 1 : 10
# Enter num 2 : 15
# Addition : 25
# Substract : -5
# Multiplication : 150
# Divition : 0.6666666666666666

# %% [markdown]
# # Write a program to create a module ‘first_word.py’, which returns the first word of any string passed. Show the working of the module, by calling the module with any suitable example.
# ### Input: ‘This is Python Programming’
# ### Output: ‘This’

# %%
# %%writefile mod.py
def first(s):
    l=s.split()
    print("First Word is :",l[0])
# Out:
# Overwriting mod.py

# %%
import mod
s=input("Enter String :")
mod.first(s)
# Out:
# Enter String : This is Python Programming
# First Word is : This

# %% [markdown]
# # Write a Python class named Student with two attributes student_name, marks. Modify the attribute values of the said class and print the original and modified values of the said attributes.

# %%
class Student:
    def __init__(self,name,mark):
        self.name=name
        self.mark=mark
s=Student("Tejas",90)
print("orignal value :")
print(s.name)
print(s.mark)
s.name="Dada"
s.mark=95
print("Modify value :")
print(s.name)
print(s.mark)
# Out:
# orignal value :
# Tejas
# 90
# Modify value :
# Dada
# 95

# %% [markdown]
# # Write a Python class named Rectangle constructed by a length and width and a method which will compute the area of a rectangle.

# %%
class rectangle:
    def __init__(self,l,w):
        self.length=l
        self.width=w
    def area(self):
        a=self.length*self.width
        print("Area Of Rectangle :",a)

# %%
l=int(input("Enter Length :"))
w=int(input("Enter Width : "))
a=rectangle(l,w)
a.area()
# Out:
# Enter Length : 10
# Enter Width :  12
# Area Of Rectangle : 120

# %% [markdown]
# # Write a Python class named Circle constructed by a radius and two methods which will compute the area and the perimeter of a circle.

# %%
class circle:
    def __init__(self,r):
        self.r=r
    def area(self):
        print("Area Of Crcle :",(3.14*self.r*self.r))
    def pera(self):
        print("Perimeter Of Crcle :",(2*3.14*self.r))

# %%
r=int(input("Enter radius :"))
a=circle(r)
a.area()
a.pera()
# Out:
# Enter radius : 5
# Area Of Crcle : 78.5
# Perimeter Of Crcle : 31.400000000000002

# %% [markdown]
# # Write a python program to demonstrate the use of try-except-else in Exception handling

# %%
try:
    l=[10,20]
    print(l[3])
except Exception as e:
    print(e)
else:
    print("No Exception")
finally:
    print("Always Print.")
# Out:
# list index out of range
# Always Print.

# %%
try:
    l=[10,20]
    print(l[1])
except Exception as e:
    print(e)
else:
    print("No Exception")
finally:
    print("Always Print.")
# Out:
# 20
# No Exception
# Always Print.

# %% [markdown]
# # Write a python program to demonstrate the use of raise in Exception handling

# %%
def add(a,b):
    return a+b
add("abc","xyz")
# Out:
# 'abcxyz'

# %%
def add(a,b):
    if type(a)==str:
        raise TypeError("a can not be String.")
    if type(b)==str:
        raise TypeError("b can not be String.")
    return a+b
add("abc","xyz")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 7
#       5         raise TypeError("b can not be String.")
#       6     return a+b
# ----> 7 add("abc","xyz")
#
# Cell In[10], line 3, in add(a, b)
#       1 def add(a,b):
#       2     if type(a)==str:
# ----> 3         raise TypeError("a can not be String.")
#       4     if type(b)==str:
#       5         raise TypeError("b can not be String.")
#
# TypeError: a can not be String.

# %%
def add(a,b):
    if type(a)==str:
        raise TypeError("a can not be String.")
    if type(b)==str:
        raise TypeError("b can not be String.")
    return a+b
add("abc",10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 7
#       5         raise TypeError("b can not be String.")
#       6     return a+b
# ----> 7 add("abc",10)
#
# Cell In[12], line 3, in add(a, b)
#       1 def add(a,b):
#       2     if type(a)==str:
# ----> 3         raise TypeError("a can not be String.")
#       4     if type(b)==str:
#       5         raise TypeError("b can not be String.")
#
# TypeError: a can not be String.

# %%
def add(a,b):
    if type(a)==str:
        raise TypeError("a can not be String.")
    if type(b)==str:
        raise TypeError("b can not be String.")
    return a+b
add(10,"xyz")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 7
#       5         raise TypeError("b can not be String.")
#       6     return a+b
# ----> 7 add(10,"xyz")
#
# Cell In[13], line 5, in add(a, b)
#       3     raise TypeError("a can not be String.")
#       4 if type(b)==str:
# ----> 5     raise TypeError("b can not be String.")
#       6 return a+b
#
# TypeError: b can not be String.

# %%
def add(a,b):
    if type(a)==str:
        raise TypeError("a can not be String.")
    if type(b)==str:
        raise TypeError("b can not be String.")
    return a+b
add(10,20)
# Out:
# 30

# %% [markdown]
# # Write a python program to demonstrate the use of custom exceptions in Exception handling.

# %%
class Tejas(Exception):
    def __init__(self,msg):
        self.msg=msg

# %%
def add(a,b):
    if type(a)==str:
        raise Tejas("a can not be String.")
    if type(b)==str:
        raise TypeError("b can not be String.")
    return a+b
add("abc",20)
# Out:
# ---------------------------------------------------------------------------
# Tejas                                     Traceback (most recent call last)
# Cell In[17], line 7
#       5         raise TypeError("b can not be String.")
#       6     return a+b
# ----> 7 add("abc",20)
#
# Cell In[17], line 3, in add(a, b)
#       1 def add(a,b):
#       2     if type(a)==str:
# ----> 3         raise Tejas("a can not be String.")
#       4     if type(b)==str:
#       5         raise TypeError("b can not be String.")
#
# Tejas: a can not be String.
