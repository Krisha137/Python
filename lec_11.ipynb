# %%
# 1. find()
# --> Returns index of first occurence of the given substring.
# --> It is not available then we will get -1.
# Syntex :
#         s.find(substring)
#         s.find(substring,begin,end)
# end is exlude.

s="Learning Python is very easy."
print(s.find("a"))
print(s.find("s"))
print(s.find("x"))
print(s.find("python"))
print(s.find("Python"))
print(s.find("a",3,15))
print(s.find("a",3,30))
# Out:
# 2
# 17
# -1
# -1
# 9
# -1
# 25

# %%
# 11. count()
# Syntex :
#         s.count(substring)
#         s.count(substring,begin,end)
# end is exlude.

s="abcdabcxyz abcdefgh"
print(s.count("a"))
print(s.count("abc"))
print(s.count("abcd"))
print(s.count("p"))
print(s.count(" "))
print(s.count("a",8,15))
# Out:
# 3
# 3
# 2
# 0
# 1
# 1

# %%
# 12. replace()
# --> To replace old string with new string 
# Syntax :
#         s.replace(oldstring,newstring)
#         s.replace(oldstring,newstring,count)
#                                       ^ time replace like if you want to replace 1 time then enter 1 

s="Learning Java is easy."
x=s.replace("Java","Python")
print(x)
# Out:
# Learning Python is easy.

# %%
# 13. split()
# split(separatior)--> we can split the string according to specified swparator by using split() method.
#                  --> Defult separator is space.
#                  --> The return type of split() method is list.

s="Hello World"
t="Hello   world"
l=s.split()
print(l)
print(t.split())
print(s.split("l"))
for i in l:
    print(i)
# Out:
# ['Hello', 'World']
# ['Hello', 'world']
# ['He', '', 'o Wor', 'd']
# Hello
# World

# %%
s="29-10-2025"
l=s.split("-")
print(l)
# Out:
# ['29', '10', '2025']

# %%
s="abcd"
l=s.split("d")
print(l)
for i in l:
    print(i)
# Out:
# ['abc', '']
# abc

# %%
# 14. translate() with maketrans() function

import string
print(string.punctuation)
print(len(string.punctuation))
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# 32

# %%
# maketrans():
#             --> make translation table
#             --> mapping of character to their replacement or to none for deletion.
# Syntax :
#         maketrance(form_chars,to_chars,delete_chars)

# translate():
#             --> Applies to translation table created by maketrans()
#             --> Returns new string with characters replaced or deleted according to table.

import string
s="Py$@th!!on."
l=s.maketrans("","",string.punctuation)
print(l)
x=s.translate(l)
print(x)
# Out:
# {33: None, 34: None, 35: None, 36: None, 37: None, 38: None, 39: None, 40: None, 41: None, 42: None, 43: None, 44: None, 45: None, 46: None, 47: None, 58: None, 59: None, 60: None, 61: None, 62: None, 63: None, 64: None, 91: None, 92: None, 93: None, 94: None, 95: None, 96: None, 123: None, 124: None, 125: None, 126: None}
# Python

# %%
# If you want to update original string then write like this.
import string
s="Py$@th!!on."
l=s.maketrans("","",string.punctuation)
print(l)
s=s.translate(l)
print(s)
# Out:
# {33: None, 34: None, 35: None, 36: None, 37: None, 38: None, 39: None, 40: None, 41: None, 42: None, 43: None, 44: None, 45: None, 46: None, 47: None, 58: None, 59: None, 60: None, 61: None, 62: None, 63: None, 64: None, 91: None, 92: None, 93: None, 94: None, 95: None, 96: None, 123: None, 124: None, 125: None, 126: None}
# Python

# %%
import string
s="Py$@th!!on."
l=s.maketrans("","","@$")
print(l)
s=s.translate(l)
print(s)
# Out:
# {64: None, 36: None}
# Pyth!!on.

# %%
import string
s="Py$@th!!on."
l=s.maketrans("n","m","@$")
print(l)
s=s.translate(l)
print(s)
# Out:
# {110: 109, 64: None, 36: None}
# Pyth!!om.

# %%
t="Hello sam!!"
x=t.maketrans("s","p")
print(t.translate(x))
# Out:
# Hello pam!!

# %%
t="Hello sam!!"
x="msa"
y="eJo"
table=t.maketrans(x,y)
print(t.translate(table))
# Out:
# Hello Joe!!

# %%
t="Hello sam!!"
x="msa"
y="eJob"
table=t.maketrans(x,y)
print(t.translate(table))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-460eba132c0e> in <module>
#       2 x="msa"
#       3 y="eJob"
# ----> 4 table=t.maketrans(x,y)
#       5 print(t.translate(table))
#
# ValueError: the first two maketrans arguments must have equal length

# %% [markdown]
# # WAP to replace eash special symbol with # in the following string.

# %%
import string
s="/*John is @devloper $ musician!!"
for i in s:
    if i in string.punctuation:
        s=s.translate(s.maketrans(i,"#"))
print(s)
# Out:
# ##John is #devloper # musician##

# %%
s="/*John is @devloper $ musician!!"
for i in string.punctuation:
    s=s.replace(i,"#")
print(s)
# Out:
# ##John is #devloper # musician##

# %% [markdown]
# # WAP to remove ith character from the string.

# %%
s="Hello World"
i=int(input("Enter index : "))
r=s[i]
print(s.replace(r,"",1))
# Out:
# Enter index : 4
# Hell World

# %%
s="Hello World"
i=int(input("Enter index : "))
r=s[:i]+s[i+1:]
print(r)
# Out:
# Enter index : 3
# Helo World

# %% [markdown]
# # WAP to find  the count of all accurencesses of a substring in a given string by ignoring the case.

# %%
s="Welcome to USA.usa is awesome.Usa is good.Usain bolt is American."
s=s.upper()
c=s.count("USA")
print(c)
# Out:
# 4

# %% [markdown]
# # WAP to display all position of substring in a given string.

# %%
s="abcdabcacdab"
f=s.find("a")
print(f)
for g in range(len(s)):
    f=s.find("a",f+1,len(s))
    if f==len(s):
        break
    print(f)
# Out:
# 0
# 4
# 7
# 10
# -1
# 0
# 4
# 7
# 10
# -1
# 0
# 4
# 7

# %%
s="abcdabcacdab"
for i in range(len(s)):
    if s[i]=="a":
        print("Position : ",i)
# Out:
# Position :  0
# Position :  4
# Position :  7
# Position :  10

# %% [markdown]
# # WAP to murge characters of two string into a single string by taking alternatively.

# %%
x="abc"
y="123"
for i in range(len(x)):
    print(x[i],end="")
    print(y[i],end="")
# Out:
# a1b2c3
